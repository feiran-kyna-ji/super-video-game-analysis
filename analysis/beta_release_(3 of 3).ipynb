# %% [markdown]
# # Super Video Game Analysis - Beta Release (3 of 3)
# Author: Feiran Ji, Chenxi Ge

# %% [markdown]
# This notebook contains the 3rd part of our analysis: we analyze difference aspects of the 3 platform groups.

# %%
import numpy as np
import pandas as pd
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
game = pd.read_csv('vg_sales_rating.csv')

# %%
game['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
plat = {}
plat['nintendo'] = ["3DS","DS","GB","GBA","N64","GC", "NES","SNES","Wii","WiiU"]
plat['sony'] = ["PS","PS2","PSP","PS3","PS4","PSV"]
plat['ms'] = ["XB","X360", "XOne"]
plat['other'] = ["GEN","SCD","DC","GG","2600","3DO","NG","PCFX","TG16",'SAT','WS','PC']

# gen = {}
# fourthgen = ["SNES", "GEN"]
# fifthgen = ["N64", "SAT","PS"]
# sixthgen = ["PS2", "GC","DC","XB"]
# seventhgen= ["Wii","X360","PS3"]

# %%
plat_new = {k: oldk for oldk, oldv in plat.items() for k in oldv}
game['Plat_Comp'] = game['Platform'].map(plat_new)
game.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating Plat_Comp
# 0          51.0          8       322.0  Nintendo      E  nintendo
# 1           NaN        NaN         NaN       NaN    NaN  nintendo
# 2          73.0        8.3       709.0  Nintendo      E  nintendo
# 3          73.0          8       192.0  Nintendo      E  nintendo
# 4           NaN        NaN         NaN       NaN    NaN  nintendo

# %%
plat_sales = game.groupby('Plat_Comp')['Global_Sales'].sum().to_frame().reset_index()

# %%
game = game[(game['Year_of_Release']<=2016)]
game['Year_of_Release'] = game['Year_of_Release'].astype(int)
game = game[pd.notnull(game['Year_of_Release'])]
game = game[pd.notnull(game['Genre'])]
game = game[pd.notnull(game['Publisher'])]
game = game[pd.notnull(game['Name'])]

# %%
game.shape
# Out:
# (16412, 17)

# %%
game.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating Plat_Comp
# 0          51.0          8       322.0  Nintendo      E  nintendo
# 1           NaN        NaN         NaN       NaN    NaN  nintendo
# 2          73.0        8.3       709.0  Nintendo      E  nintendo
# 3          73.0          8       192.0  Nintendo      E  nintendo
# 4           NaN        NaN         NaN       NaN    NaN  nintendo

# %% [markdown]
# ## Stacked bar - different game genres on platforms

# %%
game['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
data = []
for g in ['Action', 'Sports', 'Shooter', 'Role-Playing', 'Platform', 'Misc', 'Racing']:
    g_df = game[game.Genre==g].groupby('Plat_Comp')['Name'].count().to_frame().reset_index()
    data.append(
        go.Bar(
        x=list(g_df['Plat_Comp']),
        y=list(g_df['Name']),
        name=g
    ))

layout = go.Layout(title='Number of Games by Genre on each Platform',
    barmode='stack',
    xaxis=dict(title='Platform'),
    yaxis=dict(title='Number of Games')
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="e263a9c1-9e84-43ef-bffe-1d18d783355c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e263a9c1-9e84-43ef-bffe-1d18d783355c", [{"type": "bar", "x": ["ms", "nintendo", "other", "sony"], "y": [554, 1141, 230, 1381], "name": "Action"}, {"type": "bar", "x": ["ms", "nintendo", "other", "sony"], "y": [416, 779, 90, 1021], "name": "Sports"}, {"type": "bar", "x": ["ms", "nintendo", "other", "sony"], "y": [359, 249, 196, 492], "name": "Shooter"}, {"type": "bar", "x": ["ms", "nintendo", "other", "sony"], "y": [112, 512, 133, 724], "name": "Role-Playing"}, {"type": "bar", "x": ["ms", "nintendo", "other", "sony"], "y": [79, 505, 36, 258], "name": "Platform"}, {"type": "bar", "x": ["ms", "nintendo", "other", "sony"], "y": [187, 901, 45, 564], "name": "Misc"}, {"type": "bar", "x": ["ms", "nintendo", "other", "sony"], "y": [243, 366, 77, 539], "name": "Racing"}], {"title": "Number of Games by Genre on each Platform", "barmode": "stack", "xaxis": {"title": "Platform"}, "yaxis": {"title": "Number of Games"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ## Stacked bar - different rating on platforms

# %%
game['Rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
data = []
for r in ['E', 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP']:
    r_df = game[game.Rating==r].groupby('Plat_Comp')['Name'].count().to_frame().reset_index()
    data.append(
        go.Bar(
        x=list(r_df['Plat_Comp']),
        y=list(r_df['Name']),
        name=r
    ))

layout = go.Layout(title='Number of Games by Rating on each Platform',
    barmode='stack',
    xaxis=dict(title='Platform'),
    yaxis=dict(title='Number of Games')
    )

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~atlasgcx/75.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Stacked bar - Sales on platforms

# %%
data = []
for s in ['NA_Sales','EU_Sales','JP_Sales','Other_Sales']:
    p_sales = game.groupby('Plat_Comp')[s].sum().to_frame().reset_index()
    data.append(go.Bar(
                x=p_sales['Plat_Comp'],
                y=p_sales[s],
                name=s
        ))
    
layout = go.Layout(
    title='Total Sales by Region on each Platform',
    barmode='stack',
    xaxis=dict(title='Platform'),
    yaxis=dict(title='Total Sales')
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~atlasgcx/77.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Stacked bar - Sales on platforms over year

# %%
data = []
for p in list(game['Plat_Comp'].unique()):
    p_sales = game[game.Plat_Comp==p].groupby('Year_of_Release')['Global_Sales'].sum().to_frame().reset_index()
    data.append(go.Bar(
                x=p_sales['Year_of_Release'],
                y=p_sales['Global_Sales'],
                name=p
        ))
    
layout = go.Layout(
    title='Total Sales by Platform between year 1980 and 2016',
    barmode='stack',
    xaxis=dict(title='Year'),
    yaxis=dict(title='Total Sales')
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-25-de0f65d74b98> in <module>()
#      16
#      17 fig = go.Figure(data=data, layout=layout)
# ---> 18 py.iplot(fig)
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     138     if 'auto_open' not in plot_options:
#     139         plot_options['auto_open'] = False
# --> 140     url = plot(figure_or_data, **plot_options)
#     141
#     142     if isinstance(figure_or_data, dict):
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
#     235     # Check if the url needs a secret key
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Account limit reached: Your account is limited to creating 25 charts. To continue, you can override or delete existing charts or you can upgrade your account at: https://plot.ly/products/cloud

# %% [markdown]
# ## Heatmap

# %%
z = []
for p in list(game['Plat_Comp'].unique()):
    print(p)
    new_row = []
    for y in sorted(list(game['Year_of_Release'].unique())):
        new_row.append(game[(game['Year_of_Release']==y) & (game['Plat_Comp']==p)].shape[0])
    z.append(new_row)

data = [
go.Heatmap(
    z=z,
    x=sorted(list(game['Year_of_Release'].unique())),
    y=list(game['Plat_Comp'].unique()),
    colorscale='Viridis',
)
]

layout = go.Layout(
    title='Number of games released by platform between year 1980 and 2016',
    xaxis = dict(ticks='', nticks=36),
    yaxis = dict(ticks='' )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# nintendo
# ms
# sony
# other
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-26-46d0d51cedd7> in <module>()
#      23
#      24 fig = go.Figure(data=data, layout=layout)
# ---> 25 py.iplot(fig)
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     138     if 'auto_open' not in plot_options:
#     139         plot_options['auto_open'] = False
# --> 140     url = plot(figure_or_data, **plot_options)
#     141
#     142     if isinstance(figure_or_data, dict):
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
#     235     # Check if the url needs a secret key
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Account limit reached: Your account is limited to creating 25 charts. To continue, you can override or delete existing charts or you can upgrade your account at: https://plot.ly/products/cloud

# %% [markdown]
# ## Violin_plot

# %%
fig = ff.create_violin(game.loc[:, ['Plat_Comp', 'Year_of_Release']],
                       data_header='Year_of_Release', group_header='Plat_Comp',
                       rugplot=False, title='Number of Games on each Platform',
                       width=450,
                       height=400)

py.iplot(fig, filename='Multiple Violins')
# Out:
# <div id="b10b7081-f35e-453a-863d-a2e54f735b10" style="height: 400px; width: 450px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b10b7081-f35e-453a-863d-a2e54f735b10", [{"type": "scatter", "x": [-0.0010190197225790208, -0.0012822152092363626, -0.0015280278731676083, -0.0017424829575932448, -0.0019227946935253001, -0.002074485800236052, -0.002202478307987129, -0.0023023164149096457, -0.002359573770403098, -0.0023599666938850876, -0.0023033453974900205, -0.002210262166775672, -0.002115253393903673, -0.0020516501592744915, -0.00203879426424178, -0.0020794147376418165, -0.0021671033459899312, -0.0022982091250064235, -0.0024810718771592446, -0.0027364576151797638, -0.0030861219852088306, -0.0035334687834446665, -0.004049167043965859, -0.004576513650997034, -0.0050591782688069785, -0.005474334289471336, -0.005845597830410293, -0.0062241343438659774, -0.006651837959992292, -0.007133872196019046, -0.007637581031651171, -0